# %% [markdown]
# # Worksheet 03

# %% [markdown]
# ### Distance & Similarity
#
# a) In the minkowski distance, describe what the parameters p and d are.

# %% [markdown]
# In Minkowski Distance the d is mean the dimensional real space in other word, the data set size and p meant the order of norm. It's controls how the distance is measured

# %% [markdown]
# b) In your own words describe the difference between the Euclidean distance and the Manhattan distance.

# %% [markdown]
# the Euclidean distance are the distance when p = 1
# the Manhattan distance are the distance when p = 2

# %% [markdown]
# Consider A = (0, 0) and B = (1, 1). When:
#
# - p = 1, d(A, B) = 2
# - p = 2, d(A, B) = $\sqrt{2} = 1.41$
# - p = 3, d(A, B) = $2^{1/3} = 1.26$
# - p = 4, d(A, B) = $2^{1/4} = 1.19$
#
# c) Describe what you think distance would look like when p is very large.

# %% [markdown]
# Will close to one; bc when p turn to $\infty$ which mean gonna be $2^{1/\infty}$

# %% [markdown]
# d) Is the minkowski distance still a distance function when p < 1? Expain why / why not.

# %% [markdown]
# Because when the p<1 gonna will violates the triangle inequality.

# %% [markdown]
# e) when would you use cosine similarity over the euclidan distance?

# %% [markdown]
# f) what does the jaccard distance account for that the manhattan distance doesn't?
